# %%
# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Display Settings
pd.set_option('display.max_columns', None)

# Ignore Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load Dataset
df = pd.read_csv("insurance_claims.csv")

# Display first 5 rows
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
# Check number of rows and columns
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (1000, 40)

# %%
# Display dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
# Display all column names
print(df.columns.tolist())
# Out:
# ['months_as_customer', 'age', 'policy_number', 'policy_bind_date', 'policy_state', 'policy_csl', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'capital-gains', 'capital-loss', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'property_damage', 'bodily_injuries', 'witnesses', 'police_report_available', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make', 'auto_model', 'auto_year', 'fraud_reported', '_c39']

# %%
# Check missing values in each column
missing_values = df.isnull().sum()

# Display only columns with missing values
print(missing_values[missing_values > 0])
# Out:
# authorities_contacted      91
# _c39                     1000
# dtype: int64

# %%
# Check number of duplicate rows
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# Number of unique values in each column
unique_values = pd.DataFrame({
    'Column': df.columns,
    'Unique Values': [df[col].nunique() for col in df.columns]
})

unique_values
# Out:
#                          Column  Unique Values
# 0            months_as_customer            391
# 1                           age             46
# 2                 policy_number           1000
# 3              policy_bind_date            951
# 4                  policy_state              3
# 5                    policy_csl              3
# 6             policy_deductable              3
# 7         policy_annual_premium            991
# 8                umbrella_limit             11
# 9                   insured_zip            995
# 10                  insured_sex              2
# 11      insured_education_level              7
# 12           insured_occupation             14
# 13              insured_hobbies             20
# 14         insured_relationship              6
# 15                capital-gains            338
# 16                 capital-loss            354
# 17                incident_date             60
# 18                incident_type              4
# ...

# %%
# Check columns containing '?'
question_mark_counts = (df == '?').sum()

print(question_mark_counts[question_mark_counts > 0])
# Out:
# collision_type             178
# property_damage            360
# police_report_available    343
# dtype: int64

# %%
# Identify completely empty columns
empty_columns = df.columns[df.isnull().all()]

print("Completely Empty Columns:")
print(empty_columns.tolist())
# Out:
# Completely Empty Columns:
# ['_c39']

# %%
# Create a copy for cleaning
df_clean = df.copy()

# %%
# Remove completely empty columns
df_clean.dropna(axis=1, how='all', inplace=True)

print("Dataset shape after removing empty columns:", df_clean.shape)
# Out:
# Dataset shape after removing empty columns: (1000, 39)

# %%
# Replace '?' with NaN
df_clean.replace('?', np.nan, inplace=True)

# %%
# Check missing values after replacing '?'
missing_values = df_clean.isnull().sum()

print(missing_values[missing_values > 0])
# Out:
# collision_type             178
# authorities_contacted       91
# property_damage            360
# police_report_available    343
# dtype: int64

# %%
# Fill missing categorical values with mode
categorical_missing = [
    'collision_type',
    'property_damage',
    'police_report_available'
]

for col in categorical_missing:
    if col in df_clean.columns:
        df_clean[col].fillna(df_clean[col].mode()[0], inplace=True)

# %%
# Verify remaining missing values
print("Total missing values:", df_clean.isnull().sum().sum())
# Out:
# Total missing values: 91

# %%
print("Final Dataset Shape:", df_clean.shape)
print("\nTotal Missing Values:", df_clean.isnull().sum().sum())
print("\nDuplicate Rows:", df_clean.duplicated().sum())
# Out:
# Final Dataset Shape: (1000, 39)
#
# Total Missing Values: 91
#
# Duplicate Rows: 0

# %%
# Check target variable categories
print(df_clean['fraud_reported'].value_counts())
# Out:
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64

# %%
# Calculate fraud rate
fraud_rate = (df_clean['fraud_reported'].value_counts(normalize=True) * 100).round(2)

print(fraud_rate)
# Out:
# fraud_reported
# N    75.3
# Y    24.7
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(7, 5))

sns.countplot(
    data=df_clean,
    x='fraud_reported'
)

plt.title('Distribution of Fraudulent vs Legitimate Claims')
plt.xlabel('Fraud Reported')
plt.ylabel('Number of Claims')

plt.show()

# %%
plt.figure(figsize=(7, 5))

ax = sns.countplot(
    data=df_clean,
    x='fraud_reported'
)

plt.title('Distribution of Fraudulent vs Legitimate Insurance Claims',
          fontsize=14,
          fontweight='bold')

plt.xlabel('Claim Classification')
plt.ylabel('Number of Claims')

# Rename labels
ax.set_xticklabels(['Legitimate (N)', 'Fraudulent (Y)'])

# Add value labels
for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %%
def calculate_fraud_rate(data, group_column):

    fraud_analysis = (
        data.groupby(group_column)['fraud_reported']
        .apply(lambda x: (x == 'Y').mean() * 100)
        .sort_values(ascending=False)
        .reset_index()
    )

    fraud_analysis.columns = [group_column, 'Fraud Rate (%)']

    return fraud_analysis

# %%
# Calculate fraud rate by policy state
state_fraud = calculate_fraud_rate(df_clean, 'policy_state')

state_fraud
# Out:
#   policy_state  Fraud Rate (%)
# 0           OH       25.852273
# 1           IN       25.483871
# 2           IL       22.781065

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=state_fraud,
    x='policy_state',
    y='Fraud Rate (%)'
)

plt.title('Fraud Rate by Policy State', fontsize=14, fontweight='bold')
plt.xlabel('Policy State')
plt.ylabel('Fraud Rate (%)')

plt.show()

# %%
incident_fraud = calculate_fraud_rate(
    df_clean,
    'incident_type'
)

incident_fraud
# Out:
#               incident_type  Fraud Rate (%)
# 0  Single Vehicle Collision       29.032258
# 1   Multi-vehicle Collision       27.207637
# 2                Parked Car        9.523810
# 3             Vehicle Theft        8.510638

# %%
plt.figure(figsize=(9, 5))

sns.barplot(
    data=incident_fraud,
    x='incident_type',
    y='Fraud Rate (%)'
)

plt.title('Fraud Rate by Incident Type', fontsize=14, fontweight='bold')
plt.xlabel('Incident Type')
plt.ylabel('Fraud Rate (%)')

plt.xticks(rotation=15)

plt.show()

# %%
severity_fraud = calculate_fraud_rate(
    df_clean,
    'incident_severity'
)

severity_fraud
# Out:
#   incident_severity  Fraud Rate (%)
# 0      Major Damage       60.507246
# 1        Total Loss       12.857143
# 2      Minor Damage       10.734463
# 3    Trivial Damage        6.666667

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=severity_fraud,
    x='incident_severity',
    y='Fraud Rate (%)'
)

plt.title('Fraud Rate by Incident Severity',
          fontsize=14,
          fontweight='bold')

plt.xlabel('Incident Severity')
plt.ylabel('Fraud Rate (%)')

plt.show()

# %%
collision_fraud = calculate_fraud_rate(
    df_clean,
    'collision_type'
)

collision_fraud
# Out:
#     collision_type  Fraud Rate (%)
# 0  Front Collision       27.559055
# 1   Side Collision       25.362319
# 2   Rear Collision       22.765957

# %%
plt.figure(figsize=(9, 5))

sns.barplot(
    data=collision_fraud,
    x='collision_type',
    y='Fraud Rate (%)'
)

plt.title('Fraud Rate by Collision Type',
          fontsize=14,
          fontweight='bold')

plt.xlabel('Collision Type')
plt.ylabel('Fraud Rate (%)')

plt.xticks(rotation=15)

plt.show()

# %%
# Create age groups
df_clean['age_group'] = pd.cut(
    df_clean['age'],
    bins=[0, 25, 35, 45, 55, 100],
    labels=['18-25', '26-35', '36-45', '46-55', '56+']
)

# Check distribution
df_clean['age_group'].value_counts().sort_index()
# Out:
# age_group
# 18-25     40
# 26-35    352
# 36-45    385
# 46-55    159
# 56+       64
# Name: count, dtype: int64

# %%
age_fraud = calculate_fraud_rate(
    df_clean,
    'age_group'
)

age_fraud
# Out:
#   age_group  Fraud Rate (%)
# 0       56+       32.812500
# 1     18-25       30.000000
# 2     26-35       25.284091
# 3     46-55       23.270440
# 4     36-45       22.857143

# %%
plt.figure(figsize=(9, 5))

sns.barplot(
    data=age_fraud,
    x='age_group',
    y='Fraud Rate (%)'
)

plt.title('Fraud Rate by Customer Age Group',
          fontsize=14,
          fontweight='bold')

plt.xlabel('Age Group')
plt.ylabel('Fraud Rate (%)')

plt.show()

# %%
# Create customer tenure groups
df_clean['customer_tenure_group'] = pd.cut(
    df_clean['months_as_customer'],
    bins=[0, 12, 60, 120, 200, 1000],
    labels=[
        'New (0-1 Year)',
        '1-5 Years',
        '5-10 Years',
        '10-16 Years',
        '16+ Years'
    ]
)

# %%
tenure_fraud = calculate_fraud_rate(
    df_clean,
    'customer_tenure_group'
)

tenure_fraud
# Out:
#   customer_tenure_group  Fraud Rate (%)
# 0        New (0-1 Year)       29.166667
# 1            5-10 Years       25.465839
# 2             16+ Years       24.748491
# 3           10-16 Years       24.166667
# 4             1-5 Years       23.376623

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    data=tenure_fraud,
    x='customer_tenure_group',
    y='Fraud Rate (%)'
)

plt.title('Fraud Rate by Customer Tenure',
          fontsize=14,
          fontweight='bold')

plt.xlabel('Customer Tenure')
plt.ylabel('Fraud Rate (%)')

plt.xticks(rotation=15)

plt.show()

# %%
# Compare claim amounts between fraudulent and legitimate claims
claim_summary = df_clean.groupby('fraud_reported')['total_claim_amount'].agg(
    ['count', 'mean', 'median', 'min', 'max', 'sum']
)

claim_summary
# Out:
#                 count          mean   median   min     max       sum
# fraud_reported
# N                 753  50288.605578  56520.0   100  114920  37867320
# Y                 247  60302.105263  61290.0  2860  112320  14894620

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df_clean,
    x='fraud_reported',
    y='total_claim_amount'
)

plt.title('Claim Amount Distribution: Fraudulent vs Legitimate',
          fontsize=14,
          fontweight='bold')

plt.xlabel('Claim Classification')
plt.ylabel('Total Claim Amount')

plt.xticks([0, 1], ['Legitimate (N)', 'Fraudulent (Y)'])

plt.show()

# %%
# Create claim value categories using quartiles
df_clean['claim_value_category'] = pd.qcut(
    df_clean['total_claim_amount'],
    q=4,
    labels=['Low Value', 'Medium Value', 'High Value', 'Very High Value']
)

df_clean['claim_value_category'].value_counts()
# Out:
# claim_value_category
# Low Value          250
# Medium Value       250
# High Value         250
# Very High Value    250
# Name: count, dtype: int64

# %%
claim_value_fraud = calculate_fraud_rate(
    df_clean,
    'claim_value_category'
)

claim_value_fraud
# Out:
#   claim_value_category  Fraud Rate (%)
# 0      Very High Value            29.6
# 1           High Value            29.2
# 2         Medium Value            28.0
# 3            Low Value            12.0

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    data=claim_value_fraud,
    x='claim_value_category',
    y='Fraud Rate (%)'
)

plt.title('Fraud Rate by Claim Value Category',
          fontsize=14,
          fontweight='bold')

plt.xlabel('Claim Value Category')
plt.ylabel('Fraud Rate (%)')

plt.show()

# %%
# Total number of claims
total_claims = len(df_clean)

# Total fraudulent claims
fraud_cases = (df_clean['fraud_reported'] == 'Y').sum()

# Fraud rate
fraud_rate = (fraud_cases / total_claims) * 100

# Total claim amount
total_claim_value = df_clean['total_claim_amount'].sum()

# Potential fraud exposure
fraud_exposure = df_clean.loc[
    df_clean['fraud_reported'] == 'Y',
    'total_claim_amount'
].sum()

# Average claim amount
avg_claim_amount = df_clean['total_claim_amount'].mean()

# Average fraudulent claim amount
avg_fraud_claim = df_clean.loc[
    df_clean['fraud_reported'] == 'Y',
    'total_claim_amount'
].mean()

# Print KPIs
print(f"Total Claims: {total_claims:,}")
print(f"Fraud Cases: {fraud_cases:,}")
print(f"Fraud Rate: {fraud_rate:.2f}%")
print(f"Total Claim Value: ${total_claim_value:,.2f}")
print(f"Potential Fraud Exposure: ${fraud_exposure:,.2f}")
print(f"Average Claim Amount: ${avg_claim_amount:,.2f}")
print(f"Average Fraudulent Claim Amount: ${avg_fraud_claim:,.2f}")
# Out:
# Total Claims: 1,000
# Fraud Cases: 247
# Fraud Rate: 24.70%
# Total Claim Value: $52,761,940.00
# Potential Fraud Exposure: $14,894,620.00
# Average Claim Amount: $52,761.94
# Average Fraudulent Claim Amount: $60,302.11

# %%
# Fraud-associated financial exposure by policy state
state_exposure = (
    df_clean[df_clean['fraud_reported'] == 'Y']
    .groupby('policy_state')['total_claim_amount']
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

state_exposure.columns = [
    'Policy State',
    'Fraud-Associated Claim Exposure'
]

state_exposure
# Out:
#   Policy State  Fraud-Associated Claim Exposure
# 0           OH                          5496840
# 1           IN                          4867050
# 2           IL                          4530730

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=state_exposure,
    x='Policy State',
    y='Fraud-Associated Claim Exposure'
)

plt.title(
    'Fraud-Associated Financial Exposure by Policy State',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Policy State')
plt.ylabel('Fraud-Associated Claim Exposure')

plt.show()

# %%
incident_exposure = (
    df_clean[df_clean['fraud_reported'] == 'Y']
    .groupby('incident_type')['total_claim_amount']
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

incident_exposure.columns = [
    'Incident Type',
    'Fraud-Associated Claim Exposure'
]

incident_exposure
# Out:
#               Incident Type  Fraud-Associated Claim Exposure
# 0  Single Vehicle Collision                          7804240
# 1   Multi-vehicle Collision                          7008050
# 2             Vehicle Theft                            41580
# 3                Parked Car                            40750

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    data=incident_exposure,
    x='Incident Type',
    y='Fraud-Associated Claim Exposure'
)

plt.title(
    'Fraud-Associated Financial Exposure by Incident Type',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Incident Type')
plt.ylabel('Fraud-Associated Claim Exposure')

plt.xticks(rotation=15)

plt.show()

# %%
severity_exposure = (
    df_clean[df_clean['fraud_reported'] == 'Y']
    .groupby('incident_severity')['total_claim_amount']
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

severity_exposure.columns = [
    'Incident Severity',
    'Fraud-Associated Claim Exposure'
]

severity_exposure
# Out:
#   Incident Severity  Fraud-Associated Claim Exposure
# 0      Major Damage                         10707330
# 1        Total Loss                          2305490
# 2      Minor Damage                          1851570
# 3    Trivial Damage                            30230

# %%
plt.figure(figsize=(9, 5))

sns.barplot(
    data=severity_exposure,
    x='Incident Severity',
    y='Fraud-Associated Claim Exposure'
)

plt.title(
    'Fraud-Associated Financial Exposure by Incident Severity',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Incident Severity')
plt.ylabel('Fraud-Associated Claim Exposure')

plt.show()

# %%
# Fraud rate by incident type
incident_fraud_rate = (
    df_clean.groupby('incident_type')['fraud_reported']
    .apply(lambda x: (x == 'Y').mean() * 100)
    .reset_index()
)

incident_fraud_rate.columns = [
    'incident_type',
    'Fraud Rate (%)'
]

# Financial exposure by incident type
incident_fraud_exposure = (
    df_clean[df_clean['fraud_reported'] == 'Y']
    .groupby('incident_type')['total_claim_amount']
    .sum()
    .reset_index()
)

incident_fraud_exposure.columns = [
    'incident_type',
    'Fraud Exposure'
]

# Merge both analyses
incident_risk_priority = incident_fraud_rate.merge(
    incident_fraud_exposure,
    on='incident_type'
)

incident_risk_priority = incident_risk_priority.sort_values(
    by='Fraud Exposure',
    ascending=False
)

incident_risk_priority
# Out:
#               incident_type  Fraud Rate (%)  Fraud Exposure
# 2  Single Vehicle Collision       29.032258         7804240
# 0   Multi-vehicle Collision       27.207637         7008050
# 3             Vehicle Theft        8.510638           41580
# 1                Parked Car        9.523810           40750

# %%
# Convert date columns to datetime
df_clean['policy_bind_date'] = pd.to_datetime(
    df_clean['policy_bind_date']
)

df_clean['incident_date'] = pd.to_datetime(
    df_clean['incident_date']
)

# %%
# Calculate policy duration in days
df_clean['policy_duration_days'] = (
    df_clean['incident_date'] - df_clean['policy_bind_date']
).dt.days

# Display summary
df_clean['policy_duration_days'].describe()
# Out:
# count    1000.000000
# mean     4739.140000
# std      2686.430702
# min       -20.000000
# 25%      2484.000000
# 50%      4682.000000
# 75%      7068.000000
# max      9172.000000
# Name: policy_duration_days, dtype: float64

# %%
# Extract incident month
df_clean['incident_month'] = df_clean['incident_date'].dt.month

# %%
# Extract day of week
df_clean['incident_day_of_week'] = (
    df_clean['incident_date'].dt.day_name()
)

# %%
# Categorize incident time
def categorize_incident_time(hour):

    if 0 <= hour < 6:
        return 'Night'
    elif 6 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 18:
        return 'Afternoon'
    else:
        return 'Evening'

df_clean['incident_time_category'] = df_clean[
    'incident_hour_of_the_day'
].apply(categorize_incident_time)

# Check distribution
df_clean['incident_time_category'].value_counts()
# Out:
# incident_time_category
# Afternoon    271
# Evening      246
# Night        244
# Morning      239
# Name: count, dtype: int64

# %%
# Claim amount relative to annual policy premium
df_clean['claim_to_premium_ratio'] = (
    df_clean['total_claim_amount'] /
    df_clean['policy_annual_premium']
)

df_clean['claim_to_premium_ratio'].describe()
# Out:
# count    1000.000000
# mean       43.771088
# std        24.641878
# min         0.067452
# 25%        32.353492
# 50%        44.975200
# 75%        58.689165
# max       157.988148
# Name: claim_to_premium_ratio, dtype: float64

# %%
# Avoid division by zero
df_clean['injury_claim_ratio'] = np.where(
    df_clean['total_claim_amount'] > 0,
    df_clean['injury_claim'] / df_clean['total_claim_amount'],
    0
)

# %%
# Property claim proportion
df_clean['property_claim_ratio'] = np.where(
    df_clean['total_claim_amount'] > 0,
    df_clean['property_claim'] / df_clean['total_claim_amount'],
    0
)

# %%
# Vehicle claim proportion
df_clean['vehicle_claim_ratio'] = np.where(
    df_clean['total_claim_amount'] > 0,
    df_clean['vehicle_claim'] / df_clean['total_claim_amount'],
    0
)

# %%
# Display newly engineered features
new_features = [
    'policy_duration_days',
    'incident_month',
    'incident_day_of_week',
    'incident_time_category',
    'claim_to_premium_ratio',
    'injury_claim_ratio',
    'property_claim_ratio',
    'vehicle_claim_ratio'
]

df_clean[new_features].head()
# Out:
#    policy_duration_days  incident_month incident_day_of_week  \
# 0                   100               1               Sunday
# 1                  3130               1            Wednesday
# 2                  5282               2               Sunday
# 3                  8996               1             Saturday
# 4                   256               2              Tuesday
#
#   incident_time_category  claim_to_premium_ratio  injury_claim_ratio  \
# 0                  Night               50.898778            0.090909
# 1                Morning                4.234811            0.153846
# 2                Morning               24.519864            0.222222
# 3                  Night               44.782234            0.100000
# 4                Evening                4.103769            0.200000
#
#    property_claim_ratio  vehicle_claim_ratio
# 0              0.181818             0.727273
# 1              0.153846             0.692308
# ...

# %%
# Check for missing or infinite values
print("Missing values:")
print(df_clean[new_features].isnull().sum())

print("\nInfinite values:")
print(
    np.isinf(
        df_clean[
            ['policy_duration_days',
             'incident_month',
             'claim_to_premium_ratio',
             'injury_claim_ratio',
             'property_claim_ratio',
             'vehicle_claim_ratio']
        ]
    ).sum()
)
# Out:
# Missing values:
# policy_duration_days      0
# incident_month            0
# incident_day_of_week      0
# incident_time_category    0
# claim_to_premium_ratio    0
# injury_claim_ratio        0
# property_claim_ratio      0
# vehicle_claim_ratio       0
# dtype: int64
#
# Infinite values:
# policy_duration_days      0
# incident_month            0
# claim_to_premium_ratio    0
# injury_claim_ratio        0
# property_claim_ratio      0
# vehicle_claim_ratio       0
# dtype: int64

# %%
print("Dataset Shape:", df_clean.shape)
# Out:
# Dataset Shape: (1000, 50)

# %%
df_clean.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
# Create binary target variable
df_model = df_clean.copy()

df_model['fraud_reported'] = df_model['fraud_reported'].map({
    'N': 0,
    'Y': 1
})

# Check target distribution
print(df_model['fraud_reported'].value_counts())
# Out:
# fraud_reported
# 0    753
# 1    247
# Name: count, dtype: int64

# %%
# Columns to drop before ML modeling
columns_to_drop = [
    'fraud_reported',       # Target variable
    'policy_number',        # Unique identifier
    'policy_bind_date',     # Original date replaced by engineered features
    'incident_date',        # Original date replaced by engineered features
    'insured_zip',          # High-cardinality location identifier
    'incident_location'     # High-cardinality location identifier
]

X = df_model.drop(columns=columns_to_drop)
y = df_model['fraud_reported']

print("Feature Matrix Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Feature Matrix Shape: (1000, 44)
# Target Shape: (1000,)

# %%
# Drop features created only for EDA segmentation
eda_only_features = [
    'age_group',
    'customer_tenure_group',
    'claim_value_category'
]

X = X.drop(
    columns=[col for col in eda_only_features if col in X.columns]
)

print("Final Feature Matrix Shape:", X.shape)
# Out:
# Final Feature Matrix Shape: (1000, 41)

# %%
# Identify numerical and categorical columns

numerical_features = X.select_dtypes(
    include=['int64', 'float64']
).columns.tolist()

categorical_features = X.select_dtypes(
    include=['object', 'category']
).columns.tolist()

print("Number of Numerical Features:", len(numerical_features))
print("Number of Categorical Features:", len(categorical_features))

print("\nNumerical Features:")
print(numerical_features)

print("\nCategorical Features:")
print(categorical_features)
# Out:
# Number of Numerical Features: 21
# Number of Categorical Features: 19
#
# Numerical Features:
# ['months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year', 'policy_duration_days', 'claim_to_premium_ratio', 'injury_claim_ratio', 'property_claim_ratio', 'vehicle_claim_ratio']
#
# Categorical Features:
# ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'incident_day_of_week', 'incident_time_category']

# %%
# Check missing values before preprocessing
missing_before_ml = X.isnull().sum()

print(
    missing_before_ml[
        missing_before_ml > 0
    ]
)
# Out:
# authorities_contacted    91
# dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# %%
# Numerical preprocessing pipeline
numerical_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ]
)

# %%
# Categorical preprocessing pipeline
categorical_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore'))
    ]
)

# %%
# Combine numerical and categorical preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# %%
print("Final X Shape:", X.shape)
print("Target Distribution:\n")
print(y.value_counts(normalize=True))
# Out:
# Final X Shape: (1000, 41)
# Target Distribution:
#
# fraud_reported
# 0    0.753
# 1    0.247
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Set Shape:", X_train.shape)
print("Testing Set Shape:", X_test.shape)

print("\nTraining Target Distribution:")
print(y_train.value_counts(normalize=True))

print("\nTesting Target Distribution:")
print(y_test.value_counts(normalize=True))
# Out:
# Training Set Shape: (800, 41)
# Testing Set Shape: (200, 41)
#
# Training Target Distribution:
# fraud_reported
# 0    0.7525
# 1    0.2475
# Name: proportion, dtype: float64
#
# Testing Target Distribution:
# fraud_reported
# 0    0.755
# 1    0.245
# Name: proportion, dtype: float64

# %%
# !pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE

# %%
plt.figure(figsize=(7, 5))

sns.countplot(
    x=y_train
)

plt.title(
    'Training Data Class Distribution Before Balancing',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Fraud Reported (0 = Legitimate, 1 = Fraud)')
plt.ylabel('Number of Claims')

plt.show()

# %%
# Machine Learning Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Evaluation Metrics
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix
)

# %%
def evaluate_model(model, X_test, y_test):

    # Predictions
    y_pred = model.predict(X_test)

    # Probabilities
    y_prob = model.predict_proba(X_test)[:, 1]

    # Metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_prob)

    # Print Results
    print("Accuracy :", round(accuracy, 4))
    print("Precision:", round(precision, 4))
    print("Recall   :", round(recall, 4))
    print("F1 Score :", round(f1, 4))
    print("ROC-AUC  :", round(roc_auc, 4))

    print("\nClassification Report:\n")
    print(classification_report(y_test, y_pred))

    return {
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1,
        'ROC-AUC': roc_auc
    }

# %%
# Logistic Regression Pipeline

logistic_model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', LogisticRegression(
            class_weight='balanced',
            max_iter=1000,
            random_state=42
        ))
    ]
)

# Train model
logistic_model.fit(X_train, y_train)

# Evaluate
logistic_results = evaluate_model(
    logistic_model,
    X_test,
    y_test
)
# Out:
# Accuracy : 0.805
# Precision: 0.5926
# Recall   : 0.6531
# F1 Score : 0.6214
# ROC-AUC  : 0.8177
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87       151
#            1       0.59      0.65      0.62        49
#
#     accuracy                           0.81       200
#    macro avg       0.74      0.75      0.75       200
# weighted avg       0.81      0.81      0.81       200

# %%
decision_tree_model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', DecisionTreeClassifier(
            class_weight='balanced',
            max_depth=8,
            min_samples_split=10,
            random_state=42
        ))
    ]
)

# Train model
decision_tree_model.fit(X_train, y_train)

# Evaluate
decision_tree_results = evaluate_model(
    decision_tree_model,
    X_test,
    y_test
)
# Out:
# Accuracy : 0.78
# Precision: 0.5424
# Recall   : 0.6531
# F1 Score : 0.5926
# ROC-AUC  : 0.7039
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85       151
#            1       0.54      0.65      0.59        49
#
#     accuracy                           0.78       200
#    macro avg       0.71      0.74      0.72       200
# weighted avg       0.80      0.78      0.79       200

# %%
random_forest_model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', RandomForestClassifier(
            n_estimators=300,
            max_depth=12,
            min_samples_split=5,
            class_weight='balanced',
            random_state=42,
            n_jobs=-1
        ))
    ]
)

# Train model
random_forest_model.fit(X_train, y_train)

# Evaluate
random_forest_results = evaluate_model(
    random_forest_model,
    X_test,
    y_test
)
# Out:
# Accuracy : 0.8
# Precision: 0.6
# Recall   : 0.551
# F1 Score : 0.5745
# ROC-AUC  : 0.8457
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       151
#            1       0.60      0.55      0.57        49
#
#     accuracy                           0.80       200
#    macro avg       0.73      0.72      0.72       200
# weighted avg       0.79      0.80      0.80       200

# %%
model_results = pd.DataFrame({
    'Logistic Regression': logistic_results,
    'Decision Tree': decision_tree_results,
    'Random Forest': random_forest_results
}).T

model_results = model_results.sort_values(
    by='F1 Score',
    ascending=False
)

model_results
# Out:
#                      Accuracy  Precision    Recall  F1 Score   ROC-AUC
# Logistic Regression     0.805   0.592593  0.653061  0.621359  0.817678
# Decision Tree           0.780   0.542373  0.653061  0.592593  0.703946
# Random Forest           0.800   0.600000  0.551020  0.574468  0.845655

# %%
plt.figure(figsize=(10, 6))

model_results[['Precision', 'Recall', 'F1 Score', 'ROC-AUC']].plot(
    kind='bar',
    figsize=(10, 6)
)

plt.title(
    'ML Model Performance Comparison',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Models')
plt.ylabel('Score')

plt.xticks(rotation=0)

plt.legend(loc='lower right')

plt.tight_layout()
plt.show()

# %%
# !pip install xgboost

# %%
try:
    from xgboost import XGBClassifier
    print("XGBoost is successfully installed!")
except ImportError:
    print("XGBoost is not installed.")
# Out:
# XGBoost is successfully installed!

# %%
from xgboost import XGBClassifier

xgb_model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', XGBClassifier(
            n_estimators=300,
            max_depth=5,
            learning_rate=0.05,
            subsample=0.8,
            colsample_bytree=0.8,
            eval_metric='logloss',
            random_state=42
        ))
    ]
)

# Train model
xgb_model.fit(X_train, y_train)

# Evaluate model
xgb_results = evaluate_model(
    xgb_model,
    X_test,
    y_test
)
# Out:
# Accuracy : 0.785
# Precision: 0.5682
# Recall   : 0.5102
# F1 Score : 0.5376
# ROC-AUC  : 0.8227
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       151
#            1       0.57      0.51      0.54        49
#
#     accuracy                           0.79       200
#    macro avg       0.71      0.69      0.70       200
# weighted avg       0.78      0.79      0.78       200

# %%
# Add XGBoost results
model_results.loc['XGBoost'] = xgb_results

# Sort by F1 Score
model_results = model_results.sort_values(
    by='F1 Score',
    ascending=False
)

model_results
# Out:
#                      Accuracy  Precision    Recall  F1 Score   ROC-AUC
# Logistic Regression     0.805   0.592593  0.653061  0.621359  0.817678
# Decision Tree           0.780   0.542373  0.653061  0.592593  0.703946
# Random Forest           0.800   0.600000  0.551020  0.574468  0.845655
# XGBoost                 0.785   0.568182  0.510204  0.537634  0.822679

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate

# %%
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
scoring = {
    'precision': 'precision',
    'recall': 'recall',
    'f1': 'f1',
    'roc_auc': 'roc_auc'
}

# %%
models = {
    'Logistic Regression': logistic_model,
    'Decision Tree': decision_tree_model,
    'Random Forest': random_forest_model,
    'XGBoost': xgb_model
}

# %%
cv_results = []

for name, model in models.items():

    scores = cross_validate(
        model,
        X,
        y,
        cv=cv,
        scoring=scoring,
        n_jobs=-1
    )

    cv_results.append({
        'Model': name,
        'CV Precision': scores['test_precision'].mean(),
        'CV Recall': scores['test_recall'].mean(),
        'CV F1 Score': scores['test_f1'].mean(),
        'CV ROC-AUC': scores['test_roc_auc'].mean()
    })

cv_results_df = pd.DataFrame(cv_results)

cv_results_df = cv_results_df.sort_values(
    by='CV F1 Score',
    ascending=False
)

cv_results_df
# Out:
#                  Model  CV Precision  CV Recall  CV F1 Score  CV ROC-AUC
# 1        Decision Tree      0.629093   0.769306     0.690634    0.787469
# 0  Logistic Regression      0.611633   0.769878     0.677323    0.851963
# 3              XGBoost      0.656643   0.636408     0.637412    0.855457
# 2        Random Forest      0.603489   0.550857     0.569306    0.843188

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_grid_rf = {
    'model__n_estimators': [200, 300, 500],
    'model__max_depth': [None, 8, 12, 16],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4],
    'model__max_features': ['sqrt', 'log2']
}

# %%
rf_search = RandomizedSearchCV(
    estimator=random_forest_model,
    param_distributions=param_grid_rf,
    n_iter=20,
    scoring='f1',
    cv=cv,
    random_state=42,
    n_jobs=-1,
    verbose=1
)

# Train tuning process
rf_search.fit(X_train, y_train)

print("Best Parameters:")
print(rf_search.best_params_)

print("\nBest Cross-Validation F1 Score:")
print(rf_search.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters:
# {'model__n_estimators': 300, 'model__min_samples_split': 5, 'model__min_samples_leaf': 2, 'model__max_features': 'sqrt', 'model__max_depth': 8}
#
# Best Cross-Validation F1 Score:
# 0.6443668790482655

# %%
best_rf_model = rf_search.best_estimator_

best_rf_results = evaluate_model(
    best_rf_model,
    X_test,
    y_test
)
# Out:
# Accuracy : 0.815
# Precision: 0.6111
# Recall   : 0.6735
# F1 Score : 0.6408
# ROC-AUC  : 0.8378
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88       151
#            1       0.61      0.67      0.64        49
#
#     accuracy                           0.81       200
#    macro avg       0.75      0.77      0.76       200
# weighted avg       0.82      0.81      0.82       200

# %%
# Select final candidate model
final_model = best_rf_model

# %%
# Get fraud probabilities
y_prob = final_model.predict_proba(X_test)[:, 1]

# Preview probabilities
print(y_prob[:10])
# Out:
# [0.20039622 0.56913836 0.27034226 0.65356111 0.27324195 0.32409035
#  0.64660734 0.66402088 0.22597505 0.31920164]

# %%
# Define thresholds to evaluate
thresholds = np.arange(0.20, 0.81, 0.05)

threshold_results = []

for threshold in thresholds:

    # Convert probabilities into predictions
    y_pred_threshold = (y_prob >= threshold).astype(int)

    # Calculate metrics
    precision = precision_score(
        y_test,
        y_pred_threshold,
        zero_division=0
    )

    recall = recall_score(
        y_test,
        y_pred_threshold,
        zero_division=0
    )

    f1 = f1_score(
        y_test,
        y_pred_threshold,
        zero_division=0
    )

    accuracy = accuracy_score(
        y_test,
        y_pred_threshold
    )

    # Store results
    threshold_results.append({
        'Threshold': round(threshold, 2),
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    })

threshold_results_df = pd.DataFrame(threshold_results)

threshold_results_df
# Out:
#     Threshold  Accuracy  Precision    Recall  F1 Score
# 0        0.20     0.375   0.281609  1.000000  0.439462
# 1        0.25     0.445   0.303797  0.979592  0.463768
# 2        0.30     0.650   0.403670  0.897959  0.556962
# 3        0.35     0.795   0.552632  0.857143  0.672000
# 4        0.40     0.840   0.630769  0.836735  0.719298
# 5        0.45     0.840   0.634921  0.816327  0.714286
# 6        0.50     0.815   0.611111  0.673469  0.640777
# 7        0.55     0.810   0.617021  0.591837  0.604167
# 8        0.60     0.775   0.566667  0.346939  0.430380
# 9        0.65     0.740   0.411765  0.142857  0.212121
# 10       0.70     0.755   0.500000  0.040816  0.075472
# 11       0.75     0.755   0.000000  0.000000  0.000000
# 12       0.80     0.755   0.000000  0.000000  0.000000

# %%
plt.figure(figsize=(10, 6))

plt.plot(
    threshold_results_df['Threshold'],
    threshold_results_df['Precision'],
    marker='o',
    label='Precision'
)

plt.plot(
    threshold_results_df['Threshold'],
    threshold_results_df['Recall'],
    marker='o',
    label='Recall'
)

plt.plot(
    threshold_results_df['Threshold'],
    threshold_results_df['F1 Score'],
    marker='o',
    label='F1 Score'
)

plt.title(
    'Fraud Detection Performance Across Classification Thresholds',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Fraud Probability Threshold')
plt.ylabel('Score')

plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %%
# Create threshold-based financial impact analysis

financial_threshold_results = []

# Get actual claim amounts from test data
test_claim_amounts = df_model.loc[
    X_test.index,
    'total_claim_amount'
]

for threshold in thresholds:

    # Predictions based on threshold
    y_pred_threshold = (y_prob >= threshold).astype(int)

    # True fraud detected
    detected_fraud_mask = (
        (y_test.values == 1) &
        (y_pred_threshold == 1)
    )

    # Fraud exposure detected
    fraud_exposure_detected = test_claim_amounts.values[
        detected_fraud_mask
    ].sum()

    # Total alerts generated
    total_alerts = y_pred_threshold.sum()

    # False positives
    false_alerts = (
        (y_test.values == 0) &
        (y_pred_threshold == 1)
    ).sum()

    financial_threshold_results.append({
        'Threshold': round(threshold, 2),
        'Fraud Exposure Detected': fraud_exposure_detected,
        'Total Alerts': total_alerts,
        'False Alerts': false_alerts
    })

financial_threshold_df = pd.DataFrame(
    financial_threshold_results
)

financial_threshold_df
# Out:
#     Threshold  Fraud Exposure Detected  Total Alerts  False Alerts
# 0        0.20                  2998470           174           125
# 1        0.25                  2921470           158           110
# 2        0.30                  2701240           109            65
# 3        0.35                  2598690            76            34
# 4        0.40                  2594070            65            24
# 5        0.45                  2509970            63            23
# 6        0.50                  2085820            54            21
# 7        0.55                  1885470            47            18
# 8        0.60                  1092570            30            13
# 9        0.65                   463540            17            10
# 10       0.70                   152040             4             2
# 11       0.75                        0             0             0
# 12       0.80                        0             0             0

# %%
threshold_analysis = threshold_results_df.merge(
    financial_threshold_df,
    on='Threshold'
)

threshold_analysis
# Out:
#     Threshold  Accuracy  Precision    Recall  F1 Score  \
# 0        0.20     0.375   0.281609  1.000000  0.439462
# 1        0.25     0.445   0.303797  0.979592  0.463768
# 2        0.30     0.650   0.403670  0.897959  0.556962
# 3        0.35     0.795   0.552632  0.857143  0.672000
# 4        0.40     0.840   0.630769  0.836735  0.719298
# 5        0.45     0.840   0.634921  0.816327  0.714286
# 6        0.50     0.815   0.611111  0.673469  0.640777
# 7        0.55     0.810   0.617021  0.591837  0.604167
# 8        0.60     0.775   0.566667  0.346939  0.430380
# 9        0.65     0.740   0.411765  0.142857  0.212121
# 10       0.70     0.755   0.500000  0.040816  0.075472
# 11       0.75     0.755   0.000000  0.000000  0.000000
# 12       0.80     0.755   0.000000  0.000000  0.000000
#
#     Fraud Exposure Detected  Total Alerts  False Alerts
# 0                   2998470           174           125
# 1                   2921470           158           110
# ...

# %%
# Total fraud-associated claim value in test set
total_test_fraud_exposure = test_claim_amounts[
    y_test == 1
].sum()

# Calculate exposure capture rate
threshold_analysis['Fraud Exposure Capture Rate (%)'] = (
    threshold_analysis['Fraud Exposure Detected']
    / total_test_fraud_exposure
) * 100

threshold_analysis
# Out:
#     Threshold  Accuracy  Precision    Recall  F1 Score  \
# 0        0.20     0.375   0.281609  1.000000  0.439462
# 1        0.25     0.445   0.303797  0.979592  0.463768
# 2        0.30     0.650   0.403670  0.897959  0.556962
# 3        0.35     0.795   0.552632  0.857143  0.672000
# 4        0.40     0.840   0.630769  0.836735  0.719298
# 5        0.45     0.840   0.634921  0.816327  0.714286
# 6        0.50     0.815   0.611111  0.673469  0.640777
# 7        0.55     0.810   0.617021  0.591837  0.604167
# 8        0.60     0.775   0.566667  0.346939  0.430380
# 9        0.65     0.740   0.411765  0.142857  0.212121
# 10       0.70     0.755   0.500000  0.040816  0.075472
# 11       0.75     0.755   0.000000  0.000000  0.000000
# 12       0.80     0.755   0.000000  0.000000  0.000000
#
#     Fraud Exposure Detected  Total Alerts  False Alerts  \
# 0                   2998470           174           125
# 1                   2921470           158           110
# ...

# %%
# Display key threshold decision metrics
decision_columns = [
    'Threshold',
    'Precision',
    'Recall',
    'F1 Score',
    'Fraud Exposure Detected',
    'Fraud Exposure Capture Rate (%)',
    'Total Alerts',
    'False Alerts'
]

threshold_analysis[
    decision_columns
].sort_values(
    by='Fraud Exposure Capture Rate (%)',
    ascending=False
)
# Out:
#     Threshold  Precision    Recall  F1 Score  Fraud Exposure Detected  \
# 0        0.20   0.281609  1.000000  0.439462                  2998470
# 1        0.25   0.303797  0.979592  0.463768                  2921470
# 2        0.30   0.403670  0.897959  0.556962                  2701240
# 3        0.35   0.552632  0.857143  0.672000                  2598690
# 4        0.40   0.630769  0.836735  0.719298                  2594070
# 5        0.45   0.634921  0.816327  0.714286                  2509970
# 6        0.50   0.611111  0.673469  0.640777                  2085820
# 7        0.55   0.617021  0.591837  0.604167                  1885470
# 8        0.60   0.566667  0.346939  0.430380                  1092570
# 9        0.65   0.411765  0.142857  0.212121                   463540
# 10       0.70   0.500000  0.040816  0.075472                   152040
# 11       0.75   0.000000  0.000000  0.000000                        0
# ...

# %%
# Set optimal fraud probability threshold
optimal_threshold = 0.50

print(f"Selected Fraud Detection Threshold: {optimal_threshold}")
# Out:
# Selected Fraud Detection Threshold: 0.5

# %%
# Convert fraud probability into risk score
fraud_risk_score = y_prob * 100

# %%
def assign_risk_category(score):

    if score <= 25:
        return 'Low Risk'

    elif score <= 50:
        return 'Medium Risk'

    elif score <= 75:
        return 'High Risk'

    else:
        return 'Critical Risk'

# %%
def assign_recommended_action(risk_category):

    if risk_category == 'Low Risk':
        return 'Auto Process'

    elif risk_category == 'Medium Risk':
        return 'Additional Verification'

    elif risk_category == 'High Risk':
        return 'Manual Review'

    else:
        return 'Investigate Immediately'

# %%
# Create Risk Intelligence DataFrame

risk_results = pd.DataFrame({
    'Claim Index': X_test.index,
    'Actual Fraud': y_test.values,
    'Fraud Probability': y_prob,
    'Fraud Risk Score': fraud_risk_score
})

# Round probability and risk score
risk_results['Fraud Probability'] = (
    risk_results['Fraud Probability'].round(4)
)

risk_results['Fraud Risk Score'] = (
    risk_results['Fraud Risk Score'].round(2)
)

# Assign risk category
risk_results['Risk Category'] = risk_results[
    'Fraud Risk Score'
].apply(assign_risk_category)

# Assign recommended action
risk_results['Recommended Action'] = risk_results[
    'Risk Category'
].apply(assign_recommended_action)

# Apply optimized fraud classification threshold
risk_results['Predicted Fraud'] = (
    risk_results['Fraud Probability'] >= optimal_threshold
).astype(int)

# Display highest-risk claims first
risk_results = risk_results.sort_values(
    by='Fraud Risk Score',
    ascending=False
)

risk_results.head(10)
# Out:
#      Claim Index  Actual Fraud  Fraud Probability  Fraud Risk Score  \
# 112           56             0             0.7430             74.30
# 125          914             0             0.7294             72.94
# 120          915             1             0.7131             71.31
# 194          251             1             0.7069             70.69
# 171          669             0             0.6934             69.34
# 156          888             0             0.6922             69.22
# 77           128             1             0.6867             68.67
# 94           494             1             0.6854             68.54
# 119          540             0             0.6801             68.01
# 29           731             0             0.6798             67.98
#
#     Risk Category Recommended Action  Predicted Fraud
# 112     High Risk      Manual Review                1
# 125     High Risk      Manual Review                1
# 120     High Risk      Manual Review                1
# ...

# %%
def assign_risk_action(probability, threshold=optimal_threshold):

    if probability < 0.25:
        return 'Low Risk - Auto Process'

    elif probability < threshold:
        return 'Medium Risk - Additional Verification'

    elif probability < 0.75:
        return 'High Risk - Manual Review'

    else:
        return 'Critical Risk - Investigate'

# %%
risk_results['Risk Decision'] = risk_results[
    'Fraud Probability'
].apply(
    lambda x: assign_risk_action(x)
)

risk_results.head(10)
# Out:
#      Claim Index  Actual Fraud  Fraud Probability  Fraud Risk Score  \
# 112           56             0             0.7430             74.30
# 125          914             0             0.7294             72.94
# 120          915             1             0.7131             71.31
# 194          251             1             0.7069             70.69
# 171          669             0             0.6934             69.34
# 156          888             0             0.6922             69.22
# 77           128             1             0.6867             68.67
# 94           494             1             0.6854             68.54
# 119          540             0             0.6801             68.01
# 29           731             0             0.6798             67.98
#
#     Risk Category Recommended Action  Predicted Fraud  \
# 112     High Risk      Manual Review                1
# 125     High Risk      Manual Review                1
# ...

# %%
risk_distribution = (
    risk_results['Risk Category']
    .value_counts()
)

print(risk_distribution)
# Out:
# Risk Category
# Medium Risk    104
# High Risk       54
# Low Risk        42
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=risk_results,
    x='Risk Category',
    order=[
        'Low Risk',
        'Medium Risk',
        'High Risk',
        'Critical Risk'
    ]
)

plt.title(
    'Distribution of Claims by Fraud Risk Category',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Risk Category')
plt.ylabel('Number of Claims')

plt.show()

# %%
# Map total claim amounts to risk results
risk_results['Claim Amount'] = (
    df_model.loc[
        risk_results['Claim Index'],
        'total_claim_amount'
    ].values
)

risk_results.head()
# Out:
#      Claim Index  Actual Fraud  Fraud Probability  Fraud Risk Score  \
# 112           56             0             0.7430             74.30
# 125          914             0             0.7294             72.94
# 120          915             1             0.7131             71.31
# 194          251             1             0.7069             70.69
# 171          669             0             0.6934             69.34
#
#     Risk Category Recommended Action  Predicted Fraud  \
# 112     High Risk      Manual Review                1
# 125     High Risk      Manual Review                1
# 120     High Risk      Manual Review                1
# 194     High Risk      Manual Review                1
# 171     High Risk      Manual Review                1
#
#                  Risk Decision  Claim Amount
# 112  High Risk - Manual Review         56430
# 125  High Risk - Manual Review         72800
# 120  High Risk - Manual Review         71190
# ...

# %%
risk_financial_exposure = (
    risk_results
    .groupby('Risk Category')['Claim Amount']
    .agg(['count', 'sum', 'mean'])
    .reset_index()
)

risk_financial_exposure.columns = [
    'Risk Category',
    'Number of Claims',
    'Total Claim Exposure',
    'Average Claim Amount'
]

risk_financial_exposure
# Out:
#   Risk Category  Number of Claims  Total Claim Exposure  Average Claim Amount
# 0     High Risk                54               3454950          63980.555556
# 1      Low Risk                42                988130          23526.904762
# 2   Medium Risk               104               6579820          63267.500000

# %%
from sklearn.preprocessing import MinMaxScaler

# Create scaler
scaler = MinMaxScaler()

# Normalize claim amount
risk_results['Normalized Claim Amount'] = scaler.fit_transform(
    risk_results[['Claim Amount']]
)

# Investigation Priority Score
risk_results['Investigation Priority Score'] = (
    risk_results['Fraud Probability'] *
    risk_results['Normalized Claim Amount'] *
    100
)

risk_results['Investigation Priority Score'] = (
    risk_results['Investigation Priority Score'].round(2)
)

# Sort by investigation priority
investigation_priority = risk_results.sort_values(
    by='Investigation Priority Score',
    ascending=False
)

investigation_priority[
    [
        'Claim Index',
        'Fraud Probability',
        'Claim Amount',
        'Risk Category',
        'Investigation Priority Score',
        'Recommended Action'
    ]
].head(10)
# Out:
#      Claim Index  Fraud Probability  Claim Amount Risk Category  \
# 78           625             0.6751         85250     High Risk
# 194          251             0.7069         80850     High Risk
# 119          540             0.6801         83160     High Risk
# 58           755             0.6178         87900     High Risk
# 125          914             0.7294         72800     High Risk
# 120          915             0.7131         71190     High Risk
# 19            30             0.6452         75600     High Risk
# 113          817             0.6424         74800     High Risk
# 7            166             0.6640         71280     High Risk
# 176          927             0.6283         74690     High Risk
#
#      Investigation Priority Score Recommended Action
# 78                          55.56      Manual Review
# 194                         55.17      Manual Review
# 119                         54.60      Manual Review
# ...

# %%
# Select important columns for final output
final_risk_output = investigation_priority[
    [
        'Claim Index',
        'Actual Fraud',
        'Predicted Fraud',
        'Fraud Probability',
        'Fraud Risk Score',
        'Risk Category',
        'Claim Amount',
        'Investigation Priority Score',
        'Recommended Action',
        'Risk Decision'
    ]
].copy()

final_risk_output.head(10)
# Out:
#      Claim Index  Actual Fraud  Predicted Fraud  Fraud Probability  \
# 78           625             0                1             0.6751
# 194          251             1                1             0.7069
# 119          540             0                1             0.6801
# 58           755             0                1             0.6178
# 125          914             0                1             0.7294
# 120          915             1                1             0.7131
# 19            30             0                1             0.6452
# 113          817             1                1             0.6424
# 7            166             1                1             0.6640
# 176          927             1                1             0.6283
#
#      Fraud Risk Score Risk Category  Claim Amount  \
# 78              67.51     High Risk         85250
# 194             70.69     High Risk         80850
# 119             68.01     High Risk         83160
# ...

# %%
# Save final risk-scored claims
final_risk_output.to_csv(
    'risk_scored_claims.csv',
    index=False
)

print("Risk-scored claims file saved successfully!")
# Out:
# Risk-scored claims file saved successfully!

# %%
# Extract trained preprocessing and model components

trained_preprocessor = final_model.named_steps['preprocessor']

trained_classifier = final_model.named_steps['model']

print("Preprocessor:", trained_preprocessor)
print("\nClassifier:", trained_classifier)
# Out:
# Preprocessor: ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['months_as_customer', 'age',
#                                   'policy_deductable', 'policy_annual_premium',
#                                   'umbrella_limit', 'capital-gains',
#                                   'capital-loss', 'incident_hour_of_the_day',
#                                   'number_of_vehicles_involved',
#                                   'bodily_injuries', 'witnesses',
#                                   'total_claim_...
#                                  ['policy_state', 'policy_csl', 'insured_sex',
#                                   'insured_education_level',
#                                   'insured_occupation', 'insured_hobbies',
# ...

# %%
# Get transformed feature names

feature_names = trained_preprocessor.get_feature_names_out()

print("Total Transformed Features:", len(feature_names))

print("\nFirst 20 Features:")
print(feature_names[:20])
# Out:
# Total Transformed Features: 173
#
# First 20 Features:
# ['num__months_as_customer' 'num__age' 'num__policy_deductable'
#  'num__policy_annual_premium' 'num__umbrella_limit' 'num__capital-gains'
#  'num__capital-loss' 'num__incident_hour_of_the_day'
#  'num__number_of_vehicles_involved' 'num__bodily_injuries'
#  'num__witnesses' 'num__total_claim_amount' 'num__injury_claim'
#  'num__property_claim' 'num__vehicle_claim' 'num__auto_year'
#  'num__policy_duration_days' 'num__claim_to_premium_ratio'
#  'num__injury_claim_ratio' 'num__property_claim_ratio']

# %%
# Extract feature importance scores

feature_importance = pd.DataFrame({
    'Feature': feature_names,
    'Importance': trained_classifier.feature_importances_
})

# Sort by importance
feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

feature_importance.head(15)
# Out:
#                                 Feature  Importance
# 83  cat__incident_severity_Major Damage    0.144002
# 55           cat__insured_hobbies_chess    0.056169
# 84  cat__incident_severity_Minor Damage    0.054076
# 14                   num__vehicle_claim    0.037951
# 85    cat__incident_severity_Total Loss    0.036159
# 56       cat__insured_hobbies_cross-fit    0.035400
# 13                  num__property_claim    0.035310
# 17          num__claim_to_premium_ratio    0.034245
# 11              num__total_claim_amount    0.033255
# 12                    num__injury_claim    0.029848
# 0               num__months_as_customer    0.023286
# 16            num__policy_duration_days    0.022058
# 3            num__policy_annual_premium    0.021484
# 18              num__injury_claim_ratio    0.017481
# 1                              num__age    0.016919

# %%
# Select top 15 features
top_features = feature_importance.head(15)

plt.figure(figsize=(10, 7))

sns.barplot(
    data=top_features,
    x='Importance',
    y='Feature'
)

plt.title(
    'Top 15 Features Influencing Fraud Risk Prediction',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Feature Importance')
plt.ylabel('Features')

plt.tight_layout()
plt.show()

# %%
# Create readable feature names

feature_importance['Feature'] = (
    feature_importance['Feature']
    .str.replace('num__', '', regex=False)
    .str.replace('cat__', '', regex=False)
    .str.replace('_', ' ', regex=False)
)

feature_importance.head(15)
# Out:
#                            Feature  Importance
# 83  incident severity Major Damage    0.144002
# 55           insured hobbies chess    0.056169
# 84  incident severity Minor Damage    0.054076
# 14                   vehicle claim    0.037951
# 85    incident severity Total Loss    0.036159
# 56       insured hobbies cross-fit    0.035400
# 13                  property claim    0.035310
# 17          claim to premium ratio    0.034245
# 11              total claim amount    0.033255
# 12                    injury claim    0.029848
# 0               months as customer    0.023286
# 16            policy duration days    0.022058
# 3            policy annual premium    0.021484
# 18              injury claim ratio    0.017481
# 1                              age    0.016919

# %%
# Display transformed feature importance
feature_importance.head(20)
# Out:
#                            Feature  Importance
# 83  incident severity Major Damage    0.144002
# 55           insured hobbies chess    0.056169
# 84  incident severity Minor Damage    0.054076
# 14                   vehicle claim    0.037951
# 85    incident severity Total Loss    0.036159
# 56       insured hobbies cross-fit    0.035400
# 13                  property claim    0.035310
# 17          claim to premium ratio    0.034245
# 11              total claim amount    0.033255
# 12                    injury claim    0.029848
# 0               months as customer    0.023286
# 16            policy duration days    0.022058
# 3            policy annual premium    0.021484
# 18              injury claim ratio    0.017481
# 1                              age    0.016919
# 15                       auto year    0.015541
# 20             vehicle claim ratio    0.014699
# 7         incident hour of the day    0.014575
# 5                    capital-gains    0.014375
# ...

# %%
# Create a copy for grouped analysis
feature_importance_grouped = feature_importance.copy()

# Extract original feature names
def get_original_feature(feature):

    # Numerical features
    if feature in numerical_features:
        return feature

    # Engineered numerical features
    for num_feature in numerical_features:
        if feature == num_feature.replace('_', ' '):
            return num_feature

    return feature


feature_importance_grouped['Original Feature'] = (
    feature_importance_grouped['Feature']
)

feature_importance_grouped.head(10)
# Out:
#                            Feature  Importance                Original Feature
# 83  incident severity Major Damage    0.144002  incident severity Major Damage
# 55           insured hobbies chess    0.056169           insured hobbies chess
# 84  incident severity Minor Damage    0.054076  incident severity Minor Damage
# 14                   vehicle claim    0.037951                   vehicle claim
# 85    incident severity Total Loss    0.036159    incident severity Total Loss
# 56       insured hobbies cross-fit    0.035400       insured hobbies cross-fit
# 13                  property claim    0.035310                  property claim
# 17          claim to premium ratio    0.034245          claim to premium ratio
# 11              total claim amount    0.033255              total claim amount
# 12                    injury claim    0.029848                    injury claim

# %%
# Get feature names before cleaning
raw_feature_names = trained_preprocessor.get_feature_names_out()

# Create mapping dataframe
importance_raw = pd.DataFrame({
    'Transformed Feature': raw_feature_names,
    'Importance': trained_classifier.feature_importances_
})

importance_raw.head()
# Out:
#           Transformed Feature  Importance
# 0     num__months_as_customer    0.023286
# 1                    num__age    0.016919
# 2      num__policy_deductable    0.005302
# 3  num__policy_annual_premium    0.021484
# 4         num__umbrella_limit    0.006877

# %%
# Map transformed features to original feature groups

def map_original_feature(feature_name):

    # Numerical features
    if feature_name.startswith('num__'):
        return feature_name.replace('num__', '')

    # Categorical features
    if feature_name.startswith('cat__'):

        feature_without_prefix = feature_name.replace('cat__', '')

        # Match with original categorical feature names
        for feature in categorical_features:
            if feature_without_prefix.startswith(feature + '_'):
                return feature

        return feature_without_prefix

    return feature_name


importance_raw['Original Feature'] = (
    importance_raw['Transformed Feature']
    .apply(map_original_feature)
)

importance_by_original_feature = (
    importance_raw
    .groupby('Original Feature')['Importance']
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

importance_by_original_feature.head(15)
# Out:
#           Original Feature  Importance
# 0        incident_severity    0.240078
# 1          insured_hobbies    0.123464
# 2            vehicle_claim    0.037951
# 3           property_claim    0.035310
# 4   claim_to_premium_ratio    0.034245
# 5       total_claim_amount    0.033255
# 6               auto_model    0.031793
# 7             injury_claim    0.029848
# 8       insured_occupation    0.029579
# 9       months_as_customer    0.023286
# 10               auto_make    0.022115
# 11    policy_duration_days    0.022058
# 12          incident_state    0.021827
# 13   policy_annual_premium    0.021484
# 14      injury_claim_ratio    0.017481

# %%
top_original_features = importance_by_original_feature.head(15)

plt.figure(figsize=(10, 7))

sns.barplot(
    data=top_original_features,
    x='Importance',
    y='Original Feature'
)

plt.title(
    'Top Business-Level Drivers of Insurance Fraud Risk',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Aggregated Feature Importance')
plt.ylabel('Fraud Risk Drivers')

plt.tight_layout()
plt.show()

# %%
fraud_driver_summary = (
    importance_by_original_feature
    .head(10)
    .copy()
)

fraud_driver_summary['Importance (%)'] = (
    fraud_driver_summary['Importance'] * 100
).round(2)

fraud_driver_summary = fraud_driver_summary[
    ['Original Feature', 'Importance (%)']
]

fraud_driver_summary
# Out:
#          Original Feature  Importance (%)
# 0       incident_severity           24.01
# 1         insured_hobbies           12.35
# 2           vehicle_claim            3.80
# 3          property_claim            3.53
# 4  claim_to_premium_ratio            3.42
# 5      total_claim_amount            3.33
# 6              auto_model            3.18
# 7            injury_claim            2.98
# 8      insured_occupation            2.96
# 9      months_as_customer            2.33

# %%
# !pip install shap

# %%
# Transform test data using trained preprocessor

X_test_transformed = trained_preprocessor.transform(X_test)

print("Transformed Test Shape:", X_test_transformed.shape)
# Out:
# Transformed Test Shape: (200, 173)

# %%
# Transform test data using trained preprocessor
X_test_transformed = trained_preprocessor.transform(X_test)

# Convert sparse matrix to dense array if necessary
if hasattr(X_test_transformed, "toarray"):
    X_test_transformed = X_test_transformed.toarray()

# Convert to numeric NumPy array
X_test_transformed = np.asarray(
    X_test_transformed,
    dtype=np.float64
)

print("Transformed Test Shape:", X_test_transformed.shape)
print("Data Type:", X_test_transformed.dtype)
# Out:
# Transformed Test Shape: (200, 173)
# Data Type: float64

# %%
import shap

# Create TreeExplainer
explainer = shap.TreeExplainer(trained_classifier)

# Calculate SHAP values
shap_values = explainer.shap_values(
    X_test_transformed
)

print("SHAP values calculated successfully!")
# Out:
# SHAP values calculated successfully!

# %%
print(type(shap_values))

if isinstance(shap_values, list):
    print("Number of classes:", len(shap_values))
    print("SHAP shape for fraud class:", shap_values[1].shape)
else:
    print("SHAP values shape:", shap_values.shape)
# Out:
# <class 'numpy.ndarray'>
# SHAP values shape: (200, 173, 2)

# %%
# Handle different SHAP output formats

if isinstance(shap_values, list):

    # Older SHAP versions
    shap_values_fraud = shap_values[1]

elif len(shap_values.shape) == 3:

    # Newer SHAP versions
    # Select fraud class (class = 1)
    shap_values_fraud = shap_values[:, :, 1]

else:

    # Binary output already
    shap_values_fraud = shap_values


# SHAP Summary Plot
shap.summary_plot(
    shap_values_fraud,
    X_test_transformed,
    feature_names=raw_feature_names
)

# %%
# Get the highest-risk claim details
highest_risk_claim = risk_results.iloc[0]

# Get original claim index
highest_risk_claim_id = highest_risk_claim['Claim Index']

print("Highest Risk Claim Index:", highest_risk_claim_id)
print("Fraud Probability:", highest_risk_claim['Fraud Probability'])
print("Fraud Risk Score:", highest_risk_claim['Fraud Risk Score'])
print("Risk Category:", highest_risk_claim['Risk Category'])
print("Recommended Action:", highest_risk_claim['Recommended Action'])
# Out:
# Highest Risk Claim Index: 56
# Fraud Probability: 0.743
# Fraud Risk Score: 74.3
# Risk Category: High Risk
# Recommended Action: Manual Review

# %%
# Find the position of the claim in X_test

claim_position = list(X_test.index).index(
    highest_risk_claim_id
)

print("Claim Position in Test Set:", claim_position)
# Out:
# Claim Position in Test Set: 112

# %%
# Create individual SHAP explanation

shap.initjs()

shap.force_plot(
    explainer.expected_value[1]
    if isinstance(explainer.expected_value, (list, np.ndarray))
    else explainer.expected_value,

    shap_values_fraud[claim_position],

    X_test_transformed[claim_position],

    feature_names=raw_feature_names
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Create SHAP Explanation object

shap_explanation = shap.Explanation(
    values=shap_values_fraud[claim_position],
    base_values=(
        explainer.expected_value[1]
        if isinstance(explainer.expected_value, (list, np.ndarray))
        else explainer.expected_value
    ),
    data=X_test_transformed[claim_position],
    feature_names=raw_feature_names
)

# Waterfall plot
shap.plots.waterfall(
    shap_explanation,
    max_display=15
)

# %%
# Create SHAP contribution DataFrame

claim_shap_values = pd.DataFrame({
    'Feature': raw_feature_names,
    'SHAP Value': shap_values_fraud[claim_position],
    'Feature Value': X_test_transformed[claim_position]
})

# Calculate absolute impact
claim_shap_values['Absolute Impact'] = (
    claim_shap_values['SHAP Value'].abs()
)

# Sort by strongest impact
claim_shap_values = claim_shap_values.sort_values(
    by='Absolute Impact',
    ascending=False
)

claim_shap_values.head(15)
# Out:
#                                    Feature  SHAP Value  Feature Value  \
# 55              cat__insured_hobbies_chess    0.090020       1.000000
# 83     cat__incident_severity_Major Damage    0.083524       1.000000
# 84     cat__incident_severity_Minor Damage    0.022129       0.000000
# 85       cat__incident_severity_Total Loss    0.020296       0.000000
# 14                      num__vehicle_claim    0.014875       0.657299
# 45  cat__insured_occupation_prof-specialty   -0.010387       1.000000
# 13                     num__property_claim    0.009419      -0.215695
# 15                          num__auto_year   -0.008880       1.517563
# 11                 num__total_claim_amount    0.008683       0.157315
# 17             num__claim_to_premium_ratio    0.008457       0.359252
# 3               num__policy_annual_premium   -0.008118      -0.727371
# 90       cat__authorities_contacted_Police    0.007160       0.000000
# ...

# %%
claim_shap_values.head(10)
# Out:
#                                    Feature  SHAP Value  Feature Value  \
# 55              cat__insured_hobbies_chess    0.090020       1.000000
# 83     cat__incident_severity_Major Damage    0.083524       1.000000
# 84     cat__incident_severity_Minor Damage    0.022129       0.000000
# 85       cat__incident_severity_Total Loss    0.020296       0.000000
# 14                      num__vehicle_claim    0.014875       0.657299
# 45  cat__insured_occupation_prof-specialty   -0.010387       1.000000
# 13                     num__property_claim    0.009419      -0.215695
# 15                          num__auto_year   -0.008880       1.517563
# 11                 num__total_claim_amount    0.008683       0.157315
# 17             num__claim_to_premium_ratio    0.008457       0.359252
#
#     Absolute Impact
# 55         0.090020
# 83         0.083524
# 84         0.022129
# 85         0.020296
# 14         0.014875
# 45         0.010387
# 13         0.009419
# 15         0.008880
# ...

# %%
# Create readable feature names

claim_shap_values['Feature'] = (
    claim_shap_values['Feature']
    .str.replace('num__', '', regex=False)
    .str.replace('cat__', '', regex=False)
    .str.replace('_', ' ', regex=False)
)

claim_shap_values.head(15)
# Out:
#                               Feature  SHAP Value  Feature Value  \
# 55              insured hobbies chess    0.090020       1.000000
# 83     incident severity Major Damage    0.083524       1.000000
# 84     incident severity Minor Damage    0.022129       0.000000
# 85       incident severity Total Loss    0.020296       0.000000
# 14                      vehicle claim    0.014875       0.657299
# 45  insured occupation prof-specialty   -0.010387       1.000000
# 13                     property claim    0.009419      -0.215695
# 15                          auto year   -0.008880       1.517563
# 11                 total claim amount    0.008683       0.157315
# 17             claim to premium ratio    0.008457       0.359252
# 3               policy annual premium   -0.008118      -0.727371
# 90       authorities contacted Police    0.007160       0.000000
# 18                 injury claim ratio    0.006967      -2.780662
# ...

# %%
# Features contributing positively towards fraud prediction

fraud_contributors = (
    claim_shap_values[
        claim_shap_values['SHAP Value'] > 0
    ]
    .sort_values(
        by='SHAP Value',
        ascending=False
    )
)

print("Top Features Increasing Fraud Risk:\n")

fraud_contributors[
    ['Feature', 'SHAP Value']
].head(10)
# Out:
# Top Features Increasing Fraud Risk:
#                            Feature  SHAP Value
# 55           insured hobbies chess    0.090020
# 83  incident severity Major Damage    0.083524
# 84  incident severity Minor Damage    0.022129
# 85    incident severity Total Loss    0.020296
# 14                   vehicle claim    0.014875
# 13                  property claim    0.009419
# 11              total claim amount    0.008683
# 17          claim to premium ratio    0.008457
# 90    authorities contacted Police    0.007160
# 18              injury claim ratio    0.006967

# %%
# Executive Fraud Risk KPIs

executive_kpis = {

    'Total Claims': total_claims,

    'Fraud Cases': fraud_cases,

    'Fraud Rate (%)': round(fraud_rate, 2),

    'Total Claim Value': round(total_claim_value, 2),

    'Fraud-Associated Claim Exposure': round(fraud_exposure, 2),

    'Average Claim Amount': round(avg_claim_amount, 2),

    'Average Fraudulent Claim Amount': round(avg_fraud_claim, 2)
}

executive_kpis
# Out:
# {'Total Claims': 1000,
#  'Fraud Cases': np.int64(247),
#  'Fraud Rate (%)': np.float64(24.7),
#  'Total Claim Value': np.int64(52761940),
#  'Fraud-Associated Claim Exposure': np.int64(14894620),
#  'Average Claim Amount': np.float64(52761.94),
#  'Average Fraudulent Claim Amount': np.float64(60302.11)}

# %%
executive_summary = pd.DataFrame(
    executive_kpis.items(),
    columns=['Metric', 'Value']
)

executive_summary
# Out:
#                             Metric        Value
# 0                     Total Claims      1000.00
# 1                      Fraud Cases       247.00
# 2                   Fraud Rate (%)        24.70
# 3                Total Claim Value  52761940.00
# 4  Fraud-Associated Claim Exposure  14894620.00
# 5             Average Claim Amount     52761.94
# 6  Average Fraudulent Claim Amount     60302.11

# %%
# Risk Intelligence KPIs

total_test_claims = len(risk_results)

high_risk_claims = len(
    risk_results[
        risk_results['Risk Category'].isin(
            ['High Risk', 'Critical Risk']
        )
    ]
)

critical_risk_claims = len(
    risk_results[
        risk_results['Risk Category'] == 'Critical Risk'
    ]
)

claims_flagged = risk_results['Predicted Fraud'].sum()

avg_risk_score = risk_results['Fraud Risk Score'].mean()

print("Total Claims Evaluated:", total_test_claims)
print("High + Critical Risk Claims:", high_risk_claims)
print("Critical Risk Claims:", critical_risk_claims)
print("Claims Flagged as Potential Fraud:", claims_flagged)
print("Average Fraud Risk Score:", round(avg_risk_score, 2))
# Out:
# Total Claims Evaluated: 200
# High + Critical Risk Claims: 54
# Critical Risk Claims: 0
# Claims Flagged as Potential Fraud: 54
# Average Fraud Risk Score: 37.32

# %%
# Investigation workload metrics

investigation_workload = pd.DataFrame({
    'Metric': [
        'Total Claims Evaluated',
        'Claims Flagged for Investigation',
        'Investigation Rate (%)',
        'High/Critical Risk Claims'
    ],

    'Value': [
        total_test_claims,
        claims_flagged,
        round(
            (claims_flagged / total_test_claims) * 100,
            2
        ),
        high_risk_claims
    ]
})

investigation_workload
# Out:
#                              Metric  Value
# 0            Total Claims Evaluated  200.0
# 1  Claims Flagged for Investigation   54.0
# 2            Investigation Rate (%)   27.0
# 3         High/Critical Risk Claims   54.0

# %%
financial_priority_summary = (
    risk_results
    .groupby('Risk Category')
    .agg(
        Number_of_Claims=('Claim Amount', 'count'),
        Total_Exposure=('Claim Amount', 'sum'),
        Average_Claim_Value=('Claim Amount', 'mean'),
        Average_Fraud_Risk=('Fraud Risk Score', 'mean')
    )
    .reset_index()
)

# Round values
financial_priority_summary = financial_priority_summary.round(2)

financial_priority_summary
# Out:
#   Risk Category  Number_of_Claims  Total_Exposure  Average_Claim_Value  \
# 0     High Risk                54         3454950             63980.56
# 1      Low Risk                42          988130             23526.90
# 2   Medium Risk               104         6579820             63267.50
#
#    Average_Fraud_Risk
# 0               61.85
# 1               18.33
# 2               32.26

# %%
# Calculate percentage of total exposure

total_exposure = financial_priority_summary[
    'Total_Exposure'
].sum()

financial_priority_summary['Exposure Share (%)'] = (
    financial_priority_summary['Total_Exposure']
    / total_exposure
    * 100
).round(2)

financial_priority_summary.sort_values(
    by='Exposure Share (%)',
    ascending=False
)
# Out:
#   Risk Category  Number_of_Claims  Total_Exposure  Average_Claim_Value  \
# 2   Medium Risk               104         6579820             63267.50
# 0     High Risk                54         3454950             63980.56
# 1      Low Risk                42          988130             23526.90
#
#    Average_Fraud_Risk  Exposure Share (%)
# 2               32.26               59.69
# 0               61.85               31.34
# 1               18.33                8.96

# %%
def assign_priority_tier(score):

    if score >= 60:
        return 'Critical Priority'

    elif score >= 30:
        return 'High Priority'

    elif score >= 10:
        return 'Medium Priority'

    else:
        return 'Low Priority'


risk_results['Investigation Priority Tier'] = (
    risk_results['Investigation Priority Score']
    .apply(assign_priority_tier)
)

risk_results[
    [
        'Claim Index',
        'Fraud Risk Score',
        'Claim Amount',
        'Investigation Priority Score',
        'Investigation Priority Tier'
    ]
].head(10)
# Out:
#      Claim Index  Fraud Risk Score  Claim Amount  \
# 112           56             74.30         56430
# 125          914             72.94         72800
# 120          915             71.31         71190
# 194          251             70.69         80850
# 171          669             69.34         66240
# 156          888             69.22         60600
# 77           128             68.67         63840
# 94           494             68.54         64100
# 119          540             68.01         83160
# 29           731             67.98         66660
#
#      Investigation Priority Score Investigation Priority Tier
# 112                         40.45               High Priority
# 125                         51.25               High Priority
# 120                         49.00               High Priority
# 194                         55.17               High Priority
# 171                         44.33               High Priority
# ...

# %%
investigation_strategy = pd.DataFrame({
    'Priority Tier': [
        'Critical Priority',
        'High Priority',
        'Medium Priority',
        'Low Priority'
    ],

    'Recommended Action': [
        'Immediate Investigation',
        'Manual Fraud Review',
        'Request Additional Documentation',
        'Standard Claim Processing'
    ],

    'Business Objective': [
        'Prevent significant financial loss',
        'Validate suspicious claims',
        'Reduce unnecessary investigation workload',
        'Maintain operational efficiency'
    ]
})

investigation_strategy
# Out:
#        Priority Tier                Recommended Action  \
# 0  Critical Priority           Immediate Investigation
# 1      High Priority               Manual Fraud Review
# 2    Medium Priority  Request Additional Documentation
# 3       Low Priority         Standard Claim Processing
#
#                           Business Objective
# 0         Prevent significant financial loss
# 1                 Validate suspicious claims
# 2  Reduce unnecessary investigation workload
# 3            Maintain operational efficiency

# %%
print("KEY BUSINESS INSIGHTS\n")

print(
    f"1. Fraud represented approximately {fraud_rate:.2f}% "
    "of all insurance claims."
)

print(
    f"2. Historical fraud-associated claims represented "
    f"${fraud_exposure:,.2f} in potential financial exposure."
)

print(
    f"3. The fraud risk model flagged {claims_flagged} out of "
    f"{total_test_claims} evaluated claims for potential investigation."
)

print(
    f"4. {high_risk_claims} claims were classified as "
    "High or Critical Risk."
)

print(
    "5. Investigation resources can be prioritized using a combination "
    "of fraud probability and financial claim exposure."
)

print(
    "6. Explainable ML analysis identified key claim, policy, and "
    "incident characteristics associated with fraud risk."
)
# Out:
# KEY BUSINESS INSIGHTS
#
# 1. Fraud represented approximately 24.70% of all insurance claims.
# 2. Historical fraud-associated claims represented $14,894,620.00 in potential financial exposure.
# 3. The fraud risk model flagged 54 out of 200 evaluated claims for potential investigation.
# 4. 54 claims were classified as High or Critical Risk.
# 5. Investigation resources can be prioritized using a combination of fraud probability and financial claim exposure.
# 6. Explainable ML analysis identified key claim, policy, and incident characteristics associated with fraud risk.

# %%
# Export Executive Summary

executive_summary.to_csv(
    'executive_summary.csv',
    index=False
)

print("Executive summary exported successfully!")
# Out:
# Executive summary exported successfully!

# %%
executive_summary
# Out:
#                             Metric        Value
# 0                     Total Claims      1000.00
# 1                      Fraud Cases       247.00
# 2                   Fraud Rate (%)        24.70
# 3                Total Claim Value  52761940.00
# 4  Fraud-Associated Claim Exposure  14894620.00
# 5             Average Claim Amount     52761.94
# 6  Average Fraudulent Claim Amount     60302.11

# %%
# Export Threshold Analysis

threshold_analysis.to_csv(
    'threshold_analysis.csv',
    index=False
)

print("Threshold analysis exported successfully!")
# Out:
# Threshold analysis exported successfully!

# %%
threshold_analysis.head()
# Out:
#    Threshold  Accuracy  Precision    Recall  F1 Score  \
# 0       0.20     0.375   0.281609  1.000000  0.439462
# 1       0.25     0.445   0.303797  0.979592  0.463768
# 2       0.30     0.650   0.403670  0.897959  0.556962
# 3       0.35     0.795   0.552632  0.857143  0.672000
# 4       0.40     0.840   0.630769  0.836735  0.719298
#
#    Fraud Exposure Detected  Total Alerts  False Alerts  \
# 0                  2998470           174           125
# 1                  2921470           158           110
# 2                  2701240           109            65
# 3                  2598690            76            34
# 4                  2594070            65            24
#
#    Fraud Exposure Capture Rate (%)
# 0                       100.000000
# 1                        97.432024
# 2                        90.087278
# 3                        86.667200
# 4                        86.513122

# %%
# Export Fraud Driver Summary

fraud_driver_summary.to_csv(
    'fraud_driver_summary.csv',
    index=False
)

print("Fraud driver summary exported successfully!")
# Out:
# Fraud driver summary exported successfully!

# %%
fraud_driver_summary
# Out:
#          Original Feature  Importance (%)
# 0       incident_severity           24.01
# 1         insured_hobbies           12.35
# 2           vehicle_claim            3.80
# 3          property_claim            3.53
# 4  claim_to_premium_ratio            3.42
# 5      total_claim_amount            3.33
# 6              auto_model            3.18
# 7            injury_claim            2.98
# 8      insured_occupation            2.96
# 9      months_as_customer            2.33

# %%
# Export Financial Priority Summary

financial_priority_summary.to_csv(
    'financial_priority_summary.csv',
    index=False
)

print("Financial priority summary exported successfully!")
# Out:
# Financial priority summary exported successfully!

# %%
financial_priority_summary
# Out:
#   Risk Category  Number_of_Claims  Total_Exposure  Average_Claim_Value  \
# 0     High Risk                54         3454950             63980.56
# 1      Low Risk                42          988130             23526.90
# 2   Medium Risk               104         6579820             63267.50
#
#    Average_Fraud_Risk  Exposure Share (%)
# 0               61.85               31.34
# 1               18.33                8.96
# 2               32.26               59.69

# %%
# Export Investigation Workload

investigation_workload.to_csv(
    'investigation_workload.csv',
    index=False
)

print("Investigation workload exported successfully!")
# Out:
# Investigation workload exported successfully!

# %%
# Create Dashboard Master Dataset

dashboard_master = risk_results[
    [
        'Claim Index',
        'Actual Fraud',
        'Predicted Fraud',
        'Fraud Probability',
        'Fraud Risk Score',
        'Risk Category',
        'Claim Amount',
        'Investigation Priority Score',
        'Investigation Priority Tier',
        'Recommended Action'
    ]
].copy()

# Sort by highest investigation priority
dashboard_master = dashboard_master.sort_values(
    by='Investigation Priority Score',
    ascending=False
)

# Reset index
dashboard_master.reset_index(
    drop=True,
    inplace=True
)

dashboard_master.head(10)
# Out:
#    Claim Index  Actual Fraud  Predicted Fraud  Fraud Probability  \
# 0          625             0                1             0.6751
# 1          251             1                1             0.7069
# 2          540             0                1             0.6801
# 3          755             0                1             0.6178
# 4          914             0                1             0.7294
# 5          915             1                1             0.7131
# 6           30             0                1             0.6452
# 7          817             1                1             0.6424
# 8          166             1                1             0.6640
# 9          927             1                1             0.6283
#
#    Fraud Risk Score Risk Category  Claim Amount  Investigation Priority Score  \
# 0             67.51     High Risk         85250                         55.56
# 1             70.69     High Risk         80850                         55.17
# ...

# %%
# Add fraud status labels

dashboard_master['Actual Fraud Status'] = (
    dashboard_master['Actual Fraud']
    .map({
        0: 'Legitimate',
        1: 'Fraud'
    })
)

dashboard_master['Predicted Fraud Status'] = (
    dashboard_master['Predicted Fraud']
    .map({
        0: 'Not Flagged',
        1: 'Flagged'
    })
)

dashboard_master.head()
# Out:
#    Claim Index  Actual Fraud  Predicted Fraud  Fraud Probability  \
# 0          625             0                1             0.6751
# 1          251             1                1             0.7069
# 2          540             0                1             0.6801
# 3          755             0                1             0.6178
# 4          914             0                1             0.7294
#
#    Fraud Risk Score Risk Category  Claim Amount  Investigation Priority Score  \
# 0             67.51     High Risk         85250                         55.56
# 1             70.69     High Risk         80850                         55.17
# 2             68.01     High Risk         83160                         54.60
# 3             61.78     High Risk         87900                         52.43
# 4             72.94     High Risk         72800                         51.25
#
#   Investigation Priority Tier Recommended Action Actual Fraud Status  \
# ...

# %%
# Rank claims based on investigation priority

dashboard_master['Risk Rank'] = (
    dashboard_master[
        'Investigation Priority Score'
    ]
    .rank(
        ascending=False,
        method='dense'
    )
    .astype(int)
)

dashboard_master.head(10)
# Out:
#    Claim Index  Actual Fraud  Predicted Fraud  Fraud Probability  \
# 0          625             0                1             0.6751
# 1          251             1                1             0.7069
# 2          540             0                1             0.6801
# 3          755             0                1             0.6178
# 4          914             0                1             0.7294
# 5          915             1                1             0.7131
# 6           30             0                1             0.6452
# 7          817             1                1             0.6424
# 8          166             1                1             0.6640
# 9          927             1                1             0.6283
#
#    Fraud Risk Score Risk Category  Claim Amount  Investigation Priority Score  \
# 0             67.51     High Risk         85250                         55.56
# 1             70.69     High Risk         80850                         55.17
# ...

# %%
# Export master dashboard dataset

dashboard_master.to_csv(
    'dashboard_master.csv',
    index=False
)

print("Dashboard master dataset exported successfully!")
# Out:
# Dashboard master dataset exported successfully!

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'dashboard_master.csv', 'risk_scored_claims.csv', 'insurance_claims.csv', 'financial_priority_summary.csv', 'fraud_driver_summary.csv', 'investigation_workload.csv', 'threshold_analysis.csv', 'executive_summary.csv', 'sample_data']

# %%
data_dictionary = pd.DataFrame({

    'Column': [
        'Claim Index',
        'Actual Fraud',
        'Predicted Fraud',
        'Fraud Probability',
        'Fraud Risk Score',
        'Risk Category',
        'Claim Amount',
        'Investigation Priority Score',
        'Investigation Priority Tier',
        'Recommended Action',
        'Actual Fraud Status',
        'Predicted Fraud Status',
        'Risk Rank'
    ],

    'Description': [
        'Unique identifier representing the insurance claim',
        'Actual historical fraud label',
        'Model fraud classification based on selected threshold',
        'Predicted probability that the claim is fraudulent',
        'Fraud probability converted into a 0–100 risk score',
        'Business risk classification of the claim',
        'Total financial value associated with the claim',
        'Priority score combining fraud likelihood and financial exposure',
        'Operational priority level for investigation',
        'Recommended action based on claim risk level',
        'Historical classification: Fraud or Legitimate',
        'Model alert status: Flagged or Not Flagged',
        'Rank based on investigation priority score'
    ]
})

data_dictionary
# Out:
#                           Column  \
# 0                    Claim Index
# 1                   Actual Fraud
# 2                Predicted Fraud
# 3              Fraud Probability
# 4               Fraud Risk Score
# 5                  Risk Category
# 6                   Claim Amount
# 7   Investigation Priority Score
# 8    Investigation Priority Tier
# 9             Recommended Action
# 10           Actual Fraud Status
# 11        Predicted Fraud Status
# 12                     Risk Rank
#
#                                           Description
# 0   Unique identifier representing the insurance c...
# 1                       Actual historical fraud label
# 2   Model fraud classification based on selected t...
# 3   Predicted probability that the claim is fraudu...
# 4   Fraud probability converted into a 0–100 risk ...
# 5           Business risk classification of the claim
# 6     Total financial value associated with the claim
# 7   Priority score combining fraud likelihood and ...
# ...

# %%
data_dictionary.to_csv(
    'data_dictionary.csv',
    index=False
)

print("Data dictionary exported successfully!")
# Out:
# Data dictionary exported successfully!
